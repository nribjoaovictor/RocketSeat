# %%
#metodo do langchain para fazer a repartição dos documentos em chunks menores, para facilitar o processamento e a análise dos dados.
from langchain_text_splitters import RecursiveCharacterTextSplitter #importação do método de divisão de texto do langchain, que é utilizado para dividir o texto em partes menores, facilitando a análise e o processamento dos dados.
from langchain_openai import OpenAIEmbeddings #importação do método de embeddings do langchain, que é utilizado para criar representações vetoriais dos documentos, permitindo a comparação e a busca de informações relevantes com base em similaridade.
from langchain_openai import ChatOpenAI #importação do método de chat do langchain, que é utilizado para criar um modelo de linguagem baseado em chat, permitindo a interação e a geração de respostas em formato de conversa.
from langchain_community.vectorstores import Chroma #importação do método de armazenamento vetorial do langchain, que é utilizado para armazenar os vetores de embeddings dos documentos e facilitar a busca e recuperação de informações relevantes. 
from langchain_community.document_loaders import PyPDFLoader #importação do método de carregamento de documentos PDF do langchain, que é utilizado para carregar os documentos PDF e extrair o texto para análise.
from langchain.chains.question_answering import load_qa_chain #importação do método de question answering do langchain, que é utilizado para criar a cadeia de perguntas e respostas.
from langchain.chains import create_retrieval_chain #importação do método de criação de cadeia de recuperação do langchain, que é utilizado para criar uma cadeia de recuperação de informações com base nos documentos e no modelo de linguagem.
from langchain.chains.combine_documents import create_stuff_documents_chain #importação do método de combinação de documentos do langchain, que é utilizado para combinar os documentos em uma única resposta, facilitando a compreensão e a análise dos dados.
from langchain_core.prompts import ChatPromptTemplate #importação do método de template de prompt do langchain, que é utilizado para criar templates de prompts personalizados para a geração de respostas pelo modelo de linguagem.

# %%
import os

# %%
from dotenv import load_dotenv

load_dotenv()
print(os.getenv("OPENAI_API_KEY"))
# Out:
# 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

# %%
#load dos modelos - embeddings e llm
embeddings_model = OpenAIEmbeddings()
llm = ChatOpenAI(model_name="gpt-3.5-turbo", max_tokens=200)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[12], line 2
#       1 #load dos modelos - embeddings e llm
# ----> 2 embeddings_model = OpenAIEmbeddings()
#       3 llm = ChatOpenAI(model_name="gpt-3.5-turbo", max_tokens=200)
#
# File ~/RocketSeat/Trilha_IA/RAG_langchain_LlamaIndex/venv/lib/python3.11/site-packages/pydantic/v1/main.py:347, in BaseModel.__init__(__pydantic_self__, **data)
#     345 values, fields_set, validation_error = validate_model(__pydantic_self__.__class__, data)
#     346 if validation_error:
# --> 347     raise validation_error
#     348 try:
#     349     object_setattr(__pydantic_self__, '__dict__', values)
#
# ValidationError: 1 validation error for OpenAIEmbeddings
# __root__
#   Client.__init__() got an unexpected keyword argument 'proxies' (type=type_error)

# %%
import os

print("HTTP_PROXY:", os.getenv("HTTP_PROXY"))
print("HTTPS_PROXY:", os.getenv("HTTPS_PROXY"))
# Out:
# HTTP_PROXY: None
# HTTPS_PROXY: None
